# %% [markdown]
# ## Linear Regression II

# %% [markdown]
# This guide dives more into the nuts and bolts of implementing a linear regression model for prediction using PyTorch. While the conceptual basis is identical to that covered in [Linear Regression I](https://williampangbest1.github.io/machine_learning/linear_regressionI.html), we will be expanding our model to a more generaliziable case with the use of matrix operations. This guide follows closely with d2l's [implementation](https://d2l.ai/chapter_linear-regression/linear-regression-scratch.html) of linear regression, which utilizes object-orientated programming (OOP).
#
# Here's a sketch of what we'll be doing:
#
# - **Defining functions needed for OOP**<br>
# We will define two functions: one allows us to add methods into utility classes *after the class has been created*, and another allows us to directly translate function input arguments (into classes) as class attributes.
#
# - **Creating a synthetic dataset**<br>
# Once again, we will be creating a dataset based on some user-defined "ground truth" parameters. In addition, we'll also define a function that allows us to split the data into random batches (more on this in the future, but packaging data into smaller packages can be much more efficient when parallel computing is utilized)
#
# - **Defining the model**<br>
# The model relates the input and parameters to the output. We will be using the vectorized equation $\mathbf{\hat{y}} = \mathbf{Xw} + b$.
#
# - **Defining the loss function**<br>
# The loss function is an algorithim that tell us how well our predictions is doing — in essence a "rule of thumb" that computes the distance between the prediction and "true" expected output. We will be using the vectorized form of the mean squared error. In addition, we will also write a class that takes in a random batch of data and computes its gradient with respect to the input parameters (also known as stochastic gradient descent).
#
# - **Training the model**<br>
# This is the part where we make predictions, and iteratively make changes to our parameter predictions so that it gets closer and closer to the "ground-truth". To do so we:
#     - Initialize parameters (slope $m$ and bias term $b$)
#     - Repeat until done:
#         - Compute the gradient (i.e., the derivative of the loss function w.r.t parameters) of each batch
#         - Update our parameters

# %% [markdown]
# ### Object Orientated Programming
# These two functions are part of d2l's guide on diving into deep learning. For more information, please review this [chapter](https://d2l.ai/chapter_linear-regression/oo-design.html) from [d2l](https://d2l.ai) on OOPs.
#
# First, we will define a `add_method` function. This function allows us to add "methods" to class (functions in classes are called methods), which aids in understanding as we can build our tools moudlarly by sequentially adding more and more methods.

# %%
def add_method(Class):  
    def wrapper(obj):
        setattr(Class, obj.__name__, obj)
    return wrapper

# To add method to class:
# @add_method(name_of_class)
# def name_of_method():
#    ...

# %% [markdown]
# Next, we will define a `HyperParameters` utility class. This allows us to saves all arguments in a class’s \__init__ method as class attributes, hence simplying the code.

# %%
import inspect
class HyperParameters: 
    def save_hyperparameters(self, ignore=[]):
        frame = inspect.currentframe().f_back
        _, _, _, local_vars = inspect.getargvalues(frame)
        self.hparams = {k:v for k, v in local_vars.items()
                        if k not in set(ignore+['self']) and not k.startswith('_')}
        for k, v in self.hparams.items():
            setattr(self, k, v)

# %% [markdown]
# To illustrate the purpose of this utility class, let's look at two cases.

# %%
# Case 1
class printmeplease:
    def __init__(self, first_word, second_word):
        self.first_word = first_word # Defining it as class attribute
        self.second_word = second_word # Also defining it as a class attribute
        print(self.first_word + self.second_word)
        
output = printmeplease(first_word = 'Hello ', second_word = 'World');
# Out:
# Hello World

# %%
# Case 2
class printmeplease(HyperParameters):
    def __init__(self, first_word, second_word):
        self.save_hyperparameters()
        #self.first_word = first_word 
        #self.second_word = second_word
        print(self.first_word + self.second_word)
        
output = printmeplease(first_word = 'Hello ', second_word = 'World');
# Out:
# Hello World

# %% [markdown]
# As we can see in **Case 2**, defining input arguments as class attributes from the get go can make our code more compact.

# %% [markdown]
# ### Creating a synthetic dataset

# %% [markdown]
# First, we need some ground truth values. Recall that these are the values our algorithim is trying to "guess".
#
# As a reminder, the format of the linear regression is:
# $\hat{y} = w_1x_1 + w_2x_2 + b$ (generalizable as $\mathbf{y} = \mathbf{Xw} + b$).
#
# The tensor `w = torch.tensor([2, -3.4])` gives us exactly $w_1$ and $w_2$.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
import random

# Ground Truth Values
w = torch.tensor([2, -3.4]) # 2 features 
b = 4.2

# %% [markdown]
# Now, we create our synthetic data generator utility class. Note that we're creating 2000 samples. Let's breakdown the components:
#
# - `self.x` is our input matrix X (also known in ML terms as features)
# - `noise` is just a random number of *n rows* with mean 0 and variance 1 scaled by a user-defined noise value
# - `self.y` is the output of $y = XW + b + noise$ (also known in ML terms as labels)

# %%
class SyntheticRegressionData(nn.Module, HyperParameters):
    def __init__(self, w, b, batch_size, noise = 0.1, n= 2000):
        super().__init__()
        
        self.save_hyperparameters() 
        
        self.batch_size = batch_size
        self.n = n
        self.X = torch.randn(self.n, len(w))
        noise = torch.randn(self.n, 1) * noise
        self.y = torch.matmul(self.X, w.reshape((-1,1))) + b + noise

# %% [markdown]
# Now, we can generate our synthetic data. Here we see the beauty of OOP.

# %%
data = SyntheticRegressionData(w=torch.tensor([2, -3.4]), b = 4.2, batch_size = 32);

print(f'The features shape: {data.X.shape}')
print(f'The labels shape: {data.y.shape}')
print(f'First entry of features: {data.X[0]}')
print(f'First entry of labels: {data.y[0]}')
# Out:
# The features shape: torch.Size([2000, 2])
# The labels shape: torch.Size([2000, 1])
# First entry of features: tensor([-0.5301, -0.6899])
# First entry of labels: tensor([5.5020])

# %% [markdown]
# Let's now add in the method which allows us to grab a random batch of samples using the `add_method` function defined earlier.

# %%
@add_method(SyntheticRegressionData) #which is the same as saying wrapper(get_dataloader) in add_method
def get_dataloader(self):
    indices = list(range(self.n))
    random.shuffle(indices)
        
    for i in range(0, self.n, self.batch_size):
        batch_indices = torch.tensor(
            indices[i: i + self.batch_size])
        yield self.X[batch_indices], self.y[batch_indices]

# %% [markdown]
# With the method added to our `SyntheticRegressionData` utility class, we can now try and get a batch of data as defined in our `batch_size`.

# %%
for X, y in SyntheticRegressionData.get_dataloader(data):
    print('Features:', X, '\n Labels:', y)
    break
# Out:
# Features: tensor([[-6.9736e-01, -1.5922e+00],
#         [-8.7239e-01, -2.1415e-01],
#         [-4.2887e-02, -1.3465e+00],
#         [ 1.0651e+00,  1.7080e-01],
#         [-1.6511e+00, -1.1405e+00],
#         [ 5.7221e-01, -1.6894e+00],
#         [-8.1030e-01,  9.7975e-01],
#         [ 1.3062e+00, -9.9221e-01],
#         [-5.4856e-01,  1.8849e+00],
#         [ 7.6326e-01,  1.1298e+00],
#         [ 2.2546e+00,  6.6838e-01],
#         [-1.3383e+00,  5.4558e-01],
#         [ 6.1972e-01,  8.0645e-01],
#         [-2.1210e-01, -2.0688e+00],
#         [-1.0188e+00,  3.6359e-01],
#         [ 1.8891e+00, -7.6200e-01],
#         [-1.0102e+00,  7.9557e-01],
#         [ 7.5183e-01, -8.6839e-01],
#         [ 3.6415e-02, -3.6739e-01],
#         [-5.0555e-01,  1.4970e+00],
#         [-4.1458e-01,  9.4749e-01],
#         [ 3.6671e-01, -3.4895e-01],
#         [ 1.4519e-01,  1.0041e+00],
#         [ 2.6658e-01, -7.5004e-01],
#         [ 4.6444e-01,  2.6947e-01],
#         [ 3.2993e-01, -2.0760e+00],
#         [ 7.5001e-05, -9.1745e-01],
#         [ 4.4487e-01, -3.5540e-01],
#         [ 2.1876e+00, -1.5064e-01],
#         [ 1.7343e+00,  4.4517e-01],
#         [ 4.5346e-01, -1.5763e+00],
#         [-1.6033e+00,  1.5029e+00]])
#  Labels: tensor([[ 8.2576],
#         [ 3.0352],
#         [ 8.6079],
#         [ 5.7694],
#         [ 4.6765],
#         [11.1953],
#         [-1.0340],
#         [10.2451],
#         [-3.2684],
#         [ 1.9255],
#         [ 6.3621],
#         [-0.3578],
#         [ 2.6614],
#         [10.8727],
#         [ 0.8295],
#         [10.7241],
#         [-0.5780],
#         [ 8.6914],
#         [ 5.2700],
#         [-1.9259],
#         [ 0.1199],
#         [ 6.2107],
#         [ 1.1200],
#         [ 7.2653],
#         [ 4.2387],
#         [11.9594],
#         [ 7.1622],
#         [ 6.5168],
#         [ 9.1261],
#         [ 6.1227],
#         [10.4602],
#         [-4.2293]])

# %% [markdown]
# ### Defining the Model

# %%
class Model(nn.Module, HyperParameters):
    def __init__(self):
        
        num_inputs = 2 #Can change this later as an input argument
        sigma = 0.05
        
        super().__init__()
        self.save_hyperparameters()
        
        #Initializing parameters 
        self.w = torch.normal(0, sigma, (num_inputs, 1), requires_grad = True) # Normal Distribution weights
        self.b = torch.zeros(1, requires_grad = True) # Bias set to 0
        
    
    def forward(self, X):
        return torch.matmul(X, self.w) + self.b        #Returns [batch_size x 1] tensor
    
    def loss(self, y_hat, y):
        l = (y_hat - y.reshape(y_hat.shape)) ** 2 / 2   #Returns [batch_size x 1] tensor
        return l.mean() # Returns [1x1] tensor
    
    def optimizer(self):
        return SGD([self.w, self.b], 0.03); # returns self.w, self.b

# %%
class SGD(HyperParameters):
    def __init__(self, params, lr):
        self.save_hyperparameters()
        
        for param in params:
            with torch.no_grad():
                param -= lr * param.grad # value for batch_size
                #param.grad = weights.grad (differentated loss function w.r.t weights), bias.grad
                param.grad.zero_() # Reset grad to 0 (i.e., the computational graph)

# %% [markdown]
# ### Running the Model

# %%
# Grab data
data = SyntheticRegressionData(w=torch.tensor([2, -3.4]), b = 4.2, batch_size = 32)
num_epochs = 10
lr = 0.003
batch_size = 32

model = Model()
for epoch in range(num_epochs):
    for X, y in SyntheticRegressionData.get_dataloader(data):
        y_hat = model(X)
        loss = model.loss(y_hat, y) # Gives us the differentated loss function w.r.t hyperparameters
        loss.backward()
        with torch.no_grad():    
            model.optimizer()

print('Estimated w:', model.w, '\n Estimated b:', model.b)
# Out:
# Params are: [tensor([[ 0.0212],
#         [-0.0603]], requires_grad=True), tensor([0.], requires_grad=True)]
# Params are: [tensor([[ 0.1136],
#         [-0.1567]], requires_grad=True), tensor([0.], requires_grad=True)]
# Params are: [tensor([[ 0.1136],
#         [-0.1567]], requires_grad=True), tensor([0.1524], requires_grad=True)]
# Params are: [tensor([[ 0.2197],
#         [-0.2927]], requires_grad=True), tensor([0.1524], requires_grad=True)]
# Params are: [tensor([[ 0.2197],
#         [-0.2927]], requires_grad=True), tensor([0.3012], requires_grad=True)]
# Params are: [tensor([[ 0.2825],
#         [-0.4177]], requires_grad=True), tensor([0.3012], requires_grad=True)]
# Params are: [tensor([[ 0.2825],
#         [-0.4177]], requires_grad=True), tensor([0.4319], requires_grad=True)]
# Params are: [tensor([[ 0.2982],
#         [-0.5091]], requires_grad=True), tensor([0.4319], requires_grad=True)]
# Params are: [tensor([[ 0.2982],
#         [-0.5091]], requires_grad=True), tensor([0.5469], requires_grad=True)]
# Params are: [tensor([[ 0.3679],
#         [-0.5783]], requires_grad=True), tensor([0.5469], requires_grad=True)]
# Params are: [tensor([[ 0.3679],
#         [-0.5783]], requires_grad=True), tensor([0.6525], requires_grad=True)]
# Params are: [tensor([[ 0.4313],
#         [-0.6848]], requires_grad=True), tensor([0.6525], requires_grad=True)]
# Params are: [tensor([[ 0.4313],
#         [-0.6848]], requires_grad=True), tensor([0.7771], requires_grad=True)]
# Params are: [tensor([[ 0.4867],
#         [-0.7564]], requires_grad=True), tensor([0.7771], requires_grad=True)]
# Params are: [tensor([[ 0.4867],
#         [-0.7564]], requires_grad=True), tensor([0.8854], requires_grad=True)]
# Params are: [tensor([[ 0.5203],
#         [-0.8432]], requires_grad=True), tensor([0.8854], requires_grad=True)]
# Params are: [tensor([[ 0.5203],
#         [-0.8432]], requires_grad=True), tensor([1.0026], requires_grad=True)]
# Params are: [tensor([[ 0.5721],
#         [-0.9463]], requires_grad=True), tensor([1.0026], requires_grad=True)]
# Params are: [tensor([[ 0.5721],
#         [-0.9463]], requires_grad=True), tensor([1.0945], requires_grad=True)]
# Params are: [tensor([[ 0.6086],
#         [-0.9893]], requires_grad=True), tensor([1.0945], requires_grad=True)]
# Params are: [tensor([[ 0.6086],
#         [-0.9893]], requires_grad=True), tensor([1.1886], requires_grad=True)]
# Params are: [tensor([[ 0.6705],
#         [-1.0843]], requires_grad=True), tensor([1.1886], requires_grad=True)]
# Params are: [tensor([[ 0.6705],
#         [-1.0843]], requires_grad=True), tensor([1.2788], requires_grad=True)]
# Params are: [tensor([[ 0.6835],
#         [-1.1615]], requires_grad=True), tensor([1.2788], requires_grad=True)]
# Params are: [tensor([[ 0.6835],
#         [-1.1615]], requires_grad=True), tensor([1.3767], requires_grad=True)]
# Params are: [tensor([[ 0.7376],
#         [-1.2327]], requires_grad=True), tensor([1.3767], requires_grad=True)]
# Params are: [tensor([[ 0.7376],
#         [-1.2327]], requires_grad=True), tensor([1.4864], requires_grad=True)]
# Params are: [tensor([[ 0.7880],
#         [-1.2842]], requires_grad=True), tensor([1.4864], requires_grad=True)]
# Params are: [tensor([[ 0.7880],
#         [-1.2842]], requires_grad=True), tensor([1.5581], requires_grad=True)]
# Params are: [tensor([[ 0.8576],
#         [-1.3110]], requires_grad=True), tensor([1.5581], requires_grad=True)]
# Params are: [tensor([[ 0.8576],
#         [-1.3110]], requires_grad=True), tensor([1.6467], requires_grad=True)]
# Params are: [tensor([[ 0.8721],
#         [-1.3506]], requires_grad=True), tensor([1.6467], requires_grad=True)]
# Params are: [tensor([[ 0.8721],
#         [-1.3506]], requires_grad=True), tensor([1.7193], requires_grad=True)]
# Params are: [tensor([[ 0.9052],
#         [-1.4159]], requires_grad=True), tensor([1.7193], requires_grad=True)]
# Params are: [tensor([[ 0.9052],
#         [-1.4159]], requires_grad=True), tensor([1.8021], requires_grad=True)]
# Params are: [tensor([[ 0.9461],
#         [-1.4920]], requires_grad=True), tensor([1.8021], requires_grad=True)]
# Params are: [tensor([[ 0.9461],
#         [-1.4920]], requires_grad=True), tensor([1.8817], requires_grad=True)]
# Params are: [tensor([[ 0.9685],
#         [-1.5797]], requires_grad=True), tensor([1.8817], requires_grad=True)]
# Params are: [tensor([[ 0.9685],
#         [-1.5797]], requires_grad=True), tensor([1.9652], requires_grad=True)]
# Params are: [tensor([[ 1.0093],
#         [-1.6185]], requires_grad=True), tensor([1.9652], requires_grad=True)]
# Params are: [tensor([[ 1.0093],
#         [-1.6185]], requires_grad=True), tensor([2.0292], requires_grad=True)]
# Params are: [tensor([[ 1.0218],
#         [-1.6533]], requires_grad=True), tensor([2.0292], requires_grad=True)]
# Params are: [tensor([[ 1.0218],
#         [-1.6533]], requires_grad=True), tensor([2.0801], requires_grad=True)]
# Params are: [tensor([[ 1.0715],
#         [-1.7107]], requires_grad=True), tensor([2.0801], requires_grad=True)]
# Params are: [tensor([[ 1.0715],
#         [-1.7107]], requires_grad=True), tensor([2.1207], requires_grad=True)]
# Params are: [tensor([[ 1.1069],
#         [-1.7543]], requires_grad=True), tensor([2.1207], requires_grad=True)]
# Params are: [tensor([[ 1.1069],
#         [-1.7543]], requires_grad=True), tensor([2.1891], requires_grad=True)]
# Params are: [tensor([[ 1.1377],
#         [-1.7851]], requires_grad=True), tensor([2.1891], requires_grad=True)]
# Params are: [tensor([[ 1.1377],
#         [-1.7851]], requires_grad=True), tensor([2.2453], requires_grad=True)]
# Params are: [tensor([[ 1.1704],
#         [-1.8493]], requires_grad=True), tensor([2.2453], requires_grad=True)]
# Params are: [tensor([[ 1.1704],
#         [-1.8493]], requires_grad=True), tensor([2.3019], requires_grad=True)]
# Params are: [tensor([[ 1.2077],
#         [-1.9085]], requires_grad=True), tensor([2.3019], requires_grad=True)]
# Params are: [tensor([[ 1.2077],
#         [-1.9085]], requires_grad=True), tensor([2.3558], requires_grad=True)]
# Params are: [tensor([[ 1.2197],
#         [-1.9307]], requires_grad=True), tensor([2.3558], requires_grad=True)]
# Params are: [tensor([[ 1.2197],
#         [-1.9307]], requires_grad=True), tensor([2.4006], requires_grad=True)]
# Params are: [tensor([[ 1.2491],
#         [-1.9907]], requires_grad=True), tensor([2.4006], requires_grad=True)]
# Params are: [tensor([[ 1.2491],
#         [-1.9907]], requires_grad=True), tensor([2.4647], requires_grad=True)]
# Params are: [tensor([[ 1.2743],
#         [-2.0375]], requires_grad=True), tensor([2.4647], requires_grad=True)]
# Params are: [tensor([[ 1.2743],
#         [-2.0375]], requires_grad=True), tensor([2.5018], requires_grad=True)]
# Params are: [tensor([[ 1.2838],
#         [-2.0637]], requires_grad=True), tensor([2.5018], requires_grad=True)]
# Params are: [tensor([[ 1.2838],
#         [-2.0637]], requires_grad=True), tensor([2.5505], requires_grad=True)]
# Params are: [tensor([[ 1.3173],
#         [-2.1065]], requires_grad=True), tensor([2.5505], requires_grad=True)]
# Params are: [tensor([[ 1.3173],
#         [-2.1065]], requires_grad=True), tensor([2.6016], requires_grad=True)]
# Params are: [tensor([[ 1.3344],
#         [-2.1465]], requires_grad=True), tensor([2.6016], requires_grad=True)]
# Params are: [tensor([[ 1.3344],
#         [-2.1465]], requires_grad=True), tensor([2.6598], requires_grad=True)]
# Params are: [tensor([[ 1.3516],
#         [-2.1962]], requires_grad=True), tensor([2.6598], requires_grad=True)]
# Params are: [tensor([[ 1.3516],
#         [-2.1962]], requires_grad=True), tensor([2.7111], requires_grad=True)]
# Params are: [tensor([[ 1.3656],
#         [-2.2245]], requires_grad=True), tensor([2.7111], requires_grad=True)]
# Params are: [tensor([[ 1.3656],
#         [-2.2245]], requires_grad=True), tensor([2.7625], requires_grad=True)]
# Params are: [tensor([[ 1.3778],
#         [-2.2445]], requires_grad=True), tensor([2.7625], requires_grad=True)]
# Params are: [tensor([[ 1.3778],
#         [-2.2445]], requires_grad=True), tensor([2.8005], requires_grad=True)]
# Params are: [tensor([[ 1.3988],
#         [-2.2668]], requires_grad=True), tensor([2.8005], requires_grad=True)]
# Params are: [tensor([[ 1.3988],
#         [-2.2668]], requires_grad=True), tensor([2.8432], requires_grad=True)]
# Params are: [tensor([[ 1.4057],
#         [-2.2930]], requires_grad=True), tensor([2.8432], requires_grad=True)]
# Params are: [tensor([[ 1.4057],
#         [-2.2930]], requires_grad=True), tensor([2.8742], requires_grad=True)]
# Params are: [tensor([[ 1.4192],
#         [-2.3462]], requires_grad=True), tensor([2.8742], requires_grad=True)]
# Params are: [tensor([[ 1.4192],
#         [-2.3462]], requires_grad=True), tensor([2.9277], requires_grad=True)]
# Params are: [tensor([[ 1.4315],
#         [-2.3790]], requires_grad=True), tensor([2.9277], requires_grad=True)]
# Params are: [tensor([[ 1.4315],
#         [-2.3790]], requires_grad=True), tensor([2.9658], requires_grad=True)]
# Params are: [tensor([[ 1.4224],
#         [-2.4041]], requires_grad=True), tensor([2.9658], requires_grad=True)]
# Params are: [tensor([[ 1.4224],
#         [-2.4041]], requires_grad=True), tensor([3.0003], requires_grad=True)]
# Params are: [tensor([[ 1.4233],
#         [-2.4272]], requires_grad=True), tensor([3.0003], requires_grad=True)]
# Params are: [tensor([[ 1.4233],
#         [-2.4272]], requires_grad=True), tensor([3.0275], requires_grad=True)]
# Params are: [tensor([[ 1.4526],
#         [-2.4654]], requires_grad=True), tensor([3.0275], requires_grad=True)]
# Params are: [tensor([[ 1.4526],
#         [-2.4654]], requires_grad=True), tensor([3.0736], requires_grad=True)]
# Params are: [tensor([[ 1.4681],
#         [-2.4844]], requires_grad=True), tensor([3.0736], requires_grad=True)]
# Params are: [tensor([[ 1.4681],
#         [-2.4844]], requires_grad=True), tensor([3.1047], requires_grad=True)]
# Params are: [tensor([[ 1.4953],
#         [-2.5015]], requires_grad=True), tensor([3.1047], requires_grad=True)]
# Params are: [tensor([[ 1.4953],
#         [-2.5015]], requires_grad=True), tensor([3.1339], requires_grad=True)]
# Params are: [tensor([[ 1.5214],
#         [-2.5376]], requires_grad=True), tensor([3.1339], requires_grad=True)]
# Params are: [tensor([[ 1.5214],
#         [-2.5376]], requires_grad=True), tensor([3.1737], requires_grad=True)]
# Params are: [tensor([[ 1.5406],
#         [-2.5564]], requires_grad=True), tensor([3.1737], requires_grad=True)]
# Params are: [tensor([[ 1.5406],
#         [-2.5564]], requires_grad=True), tensor([3.2023], requires_grad=True)]
# Params are: [tensor([[ 1.5628],
#         [-2.5788]], requires_grad=True), tensor([3.2023], requires_grad=True)]
# Params are: [tensor([[ 1.5628],
#         [-2.5788]], requires_grad=True), tensor([3.2370], requires_grad=True)]
# Params are: [tensor([[ 1.5728],
#         [-2.5974]], requires_grad=True), tensor([3.2370], requires_grad=True)]
# Params are: [tensor([[ 1.5728],
#         [-2.5974]], requires_grad=True), tensor([3.2628], requires_grad=True)]
# Params are: [tensor([[ 1.5893],
#         [-2.6396]], requires_grad=True), tensor([3.2628], requires_grad=True)]
# Params are: [tensor([[ 1.5893],
#         [-2.6396]], requires_grad=True), tensor([3.2931], requires_grad=True)]
# Params are: [tensor([[ 1.5961],
#         [-2.6727]], requires_grad=True), tensor([3.2931], requires_grad=True)]
# Params are: [tensor([[ 1.5961],
#         [-2.6727]], requires_grad=True), tensor([3.3311], requires_grad=True)]
# Params are: [tensor([[ 1.6087],
#         [-2.7008]], requires_grad=True), tensor([3.3311], requires_grad=True)]
# Params are: [tensor([[ 1.6087],
#         [-2.7008]], requires_grad=True), tensor([3.3593], requires_grad=True)]
# Params are: [tensor([[ 1.6263],
#         [-2.7166]], requires_grad=True), tensor([3.3593], requires_grad=True)]
# Params are: [tensor([[ 1.6263],
#         [-2.7166]], requires_grad=True), tensor([3.3912], requires_grad=True)]
# Params are: [tensor([[ 1.6342],
#         [-2.7271]], requires_grad=True), tensor([3.3912], requires_grad=True)]
# Params are: [tensor([[ 1.6342],
#         [-2.7271]], requires_grad=True), tensor([3.4140], requires_grad=True)]
# Params are: [tensor([[ 1.6406],
#         [-2.7414]], requires_grad=True), tensor([3.4140], requires_grad=True)]
# Params are: [tensor([[ 1.6406],
#         [-2.7414]], requires_grad=True), tensor([3.4374], requires_grad=True)]
# Params are: [tensor([[ 1.6472],
#         [-2.7604]], requires_grad=True), tensor([3.4374], requires_grad=True)]
# Params are: [tensor([[ 1.6472],
#         [-2.7604]], requires_grad=True), tensor([3.4529], requires_grad=True)]
# Params are: [tensor([[ 1.6604],
#         [-2.7851]], requires_grad=True), tensor([3.4529], requires_grad=True)]
# Params are: [tensor([[ 1.6604],
#         [-2.7851]], requires_grad=True), tensor([3.4810], requires_grad=True)]
# Params are: [tensor([[ 1.6635],
#         [-2.8063]], requires_grad=True), tensor([3.4810], requires_grad=True)]
# Params are: [tensor([[ 1.6635],
#         [-2.8063]], requires_grad=True), tensor([3.5038], requires_grad=True)]
# Params are: [tensor([[ 1.6731],
#         [-2.8243]], requires_grad=True), tensor([3.5038], requires_grad=True)]
# Params are: [tensor([[ 1.6731],
#         [-2.8243]], requires_grad=True), tensor([3.5264], requires_grad=True)]
# Params are: [tensor([[ 1.6765],
#         [-2.8365]], requires_grad=True), tensor([3.5264], requires_grad=True)]
# Params are: [tensor([[ 1.6765],
#         [-2.8365]], requires_grad=True), tensor([3.5454], requires_grad=True)]
# Params are: [tensor([[ 1.6890],
#         [-2.8592]], requires_grad=True), tensor([3.5454], requires_grad=True)]
# Params are: [tensor([[ 1.6890],
#         [-2.8592]], requires_grad=True), tensor([3.5677], requires_grad=True)]
# Params are: [tensor([[ 1.7143],
#         [-2.8676]], requires_grad=True), tensor([3.5677], requires_grad=True)]
# Params are: [tensor([[ 1.7143],
#         [-2.8676]], requires_grad=True), tensor([3.5923], requires_grad=True)]
# Params are: [tensor([[ 1.7247],
#         [-2.8844]], requires_grad=True), tensor([3.5923], requires_grad=True)]
# Params are: [tensor([[ 1.7247],
#         [-2.8844]], requires_grad=True), tensor([3.6100], requires_grad=True)]
# Params are: [tensor([[ 1.7257],
#         [-2.8966]], requires_grad=True), tensor([3.6100], requires_grad=True)]
# Params are: [tensor([[ 1.7257],
#         [-2.8966]], requires_grad=True), tensor([3.6282], requires_grad=True)]
# Params are: [tensor([[ 1.7354],
#         [-2.9024]], requires_grad=True), tensor([3.6282], requires_grad=True)]
# Params are: [tensor([[ 1.7354],
#         [-2.9024]], requires_grad=True), tensor([3.6426], requires_grad=True)]
# Params are: [tensor([[ 1.7474],
#         [-2.9181]], requires_grad=True), tensor([3.6426], requires_grad=True)]
# Params are: [tensor([[ 1.7474],
#         [-2.9181]], requires_grad=True), tensor([3.6572], requires_grad=True)]
# Params are: [tensor([[ 1.7681],
#         [-2.9318]], requires_grad=True), tensor([3.6572], requires_grad=True)]
# Params are: [tensor([[ 1.7681],
#         [-2.9318]], requires_grad=True), tensor([3.6751], requires_grad=True)]
# Params are: [tensor([[ 1.7764],
#         [-2.9465]], requires_grad=True), tensor([3.6751], requires_grad=True)]
# Params are: [tensor([[ 1.7764],
#         [-2.9465]], requires_grad=True), tensor([3.6939], requires_grad=True)]
# Params are: [tensor([[ 1.7841],
#         [-2.9549]], requires_grad=True), tensor([3.6939], requires_grad=True)]
# Params are: [tensor([[ 1.7841],
#         [-2.9549]], requires_grad=True), tensor([3.7123], requires_grad=True)]
# Params are: [tensor([[ 1.7882],
#         [-2.9700]], requires_grad=True), tensor([3.7123], requires_grad=True)]
# Params are: [tensor([[ 1.7882],
#         [-2.9700]], requires_grad=True), tensor([3.7249], requires_grad=True)]
# Params are: [tensor([[ 1.7938],
#         [-2.9841]], requires_grad=True), tensor([3.7249], requires_grad=True)]
# Params are: [tensor([[ 1.7938],
#         [-2.9841]], requires_grad=True), tensor([3.7406], requires_grad=True)]
# Params are: [tensor([[ 1.8074],
#         [-3.0003]], requires_grad=True), tensor([3.7406], requires_grad=True)]
# Params are: [tensor([[ 1.8074],
#         [-3.0003]], requires_grad=True), tensor([3.7516], requires_grad=True)]
# Params are: [tensor([[ 1.8107],
#         [-3.0068]], requires_grad=True), tensor([3.7516], requires_grad=True)]
# Params are: [tensor([[ 1.8107],
#         [-3.0068]], requires_grad=True), tensor([3.7659], requires_grad=True)]
# Params are: [tensor([[ 1.8152],
#         [-3.0131]], requires_grad=True), tensor([3.7659], requires_grad=True)]
# Params are: [tensor([[ 1.8152],
#         [-3.0131]], requires_grad=True), tensor([3.7778], requires_grad=True)]
# Params are: [tensor([[ 1.8201],
#         [-3.0308]], requires_grad=True), tensor([3.7778], requires_grad=True)]
# Params are: [tensor([[ 1.8201],
#         [-3.0308]], requires_grad=True), tensor([3.7946], requires_grad=True)]
# Params are: [tensor([[ 1.8266],
#         [-3.0474]], requires_grad=True), tensor([3.7946], requires_grad=True)]
# Params are: [tensor([[ 1.8266],
#         [-3.0474]], requires_grad=True), tensor([3.8088], requires_grad=True)]
# Params are: [tensor([[ 1.8259],
#         [-3.0547]], requires_grad=True), tensor([3.8088], requires_grad=True)]
# Params are: [tensor([[ 1.8259],
#         [-3.0547]], requires_grad=True), tensor([3.8181], requires_grad=True)]
# Params are: [tensor([[ 1.8299],
#         [-3.0652]], requires_grad=True), tensor([3.8181], requires_grad=True)]
# Params are: [tensor([[ 1.8299],
#         [-3.0652]], requires_grad=True), tensor([3.8275], requires_grad=True)]
# Params are: [tensor([[ 1.8323],
#         [-3.0750]], requires_grad=True), tensor([3.8275], requires_grad=True)]
# Params are: [tensor([[ 1.8323],
#         [-3.0750]], requires_grad=True), tensor([3.8370], requires_grad=True)]
# Params are: [tensor([[ 1.8436],
#         [-3.0834]], requires_grad=True), tensor([3.8370], requires_grad=True)]
# Params are: [tensor([[ 1.8436],
#         [-3.0834]], requires_grad=True), tensor([3.8491], requires_grad=True)]
# Params are: [tensor([[ 1.8482],
#         [-3.0876]], requires_grad=True), tensor([3.8491], requires_grad=True)]
# Params are: [tensor([[ 1.8482],
#         [-3.0876]], requires_grad=True), tensor([3.8602], requires_grad=True)]
# Params are: [tensor([[ 1.8538],
#         [-3.0937]], requires_grad=True), tensor([3.8602], requires_grad=True)]
# Params are: [tensor([[ 1.8538],
#         [-3.0937]], requires_grad=True), tensor([3.8682], requires_grad=True)]
# Params are: [tensor([[ 1.8597],
#         [-3.1133]], requires_grad=True), tensor([3.8682], requires_grad=True)]
# Params are: [tensor([[ 1.8597],
#         [-3.1133]], requires_grad=True), tensor([3.8818], requires_grad=True)]
# Params are: [tensor([[ 1.8684],
#         [-3.1201]], requires_grad=True), tensor([3.8818], requires_grad=True)]
# Params are: [tensor([[ 1.8684],
#         [-3.1201]], requires_grad=True), tensor([3.8920], requires_grad=True)]
# Params are: [tensor([[ 1.8714],
#         [-3.1269]], requires_grad=True), tensor([3.8920], requires_grad=True)]
# Params are: [tensor([[ 1.8714],
#         [-3.1269]], requires_grad=True), tensor([3.8997], requires_grad=True)]
# Params are: [tensor([[ 1.8743],
#         [-3.1317]], requires_grad=True), tensor([3.8997], requires_grad=True)]
# Params are: [tensor([[ 1.8743],
#         [-3.1317]], requires_grad=True), tensor([3.9074], requires_grad=True)]
# Params are: [tensor([[ 1.8753],
#         [-3.1377]], requires_grad=True), tensor([3.9074], requires_grad=True)]
# Params are: [tensor([[ 1.8753],
#         [-3.1377]], requires_grad=True), tensor([3.9145], requires_grad=True)]
# Params are: [tensor([[ 1.8757],
#         [-3.1417]], requires_grad=True), tensor([3.9145], requires_grad=True)]
# Params are: [tensor([[ 1.8757],
#         [-3.1417]], requires_grad=True), tensor([3.9216], requires_grad=True)]
# Params are: [tensor([[ 1.8767],
#         [-3.1454]], requires_grad=True), tensor([3.9216], requires_grad=True)]
# Params are: [tensor([[ 1.8767],
#         [-3.1454]], requires_grad=True), tensor([3.9298], requires_grad=True)]
# Params are: [tensor([[ 1.8761],
#         [-3.1548]], requires_grad=True), tensor([3.9298], requires_grad=True)]
# Params are: [tensor([[ 1.8761],
#         [-3.1548]], requires_grad=True), tensor([3.9372], requires_grad=True)]
# Params are: [tensor([[ 1.8828],
#         [-3.1606]], requires_grad=True), tensor([3.9372], requires_grad=True)]
# Params are: [tensor([[ 1.8828],
#         [-3.1606]], requires_grad=True), tensor([3.9478], requires_grad=True)]
# Params are: [tensor([[ 1.8865],
#         [-3.1659]], requires_grad=True), tensor([3.9478], requires_grad=True)]
# Params are: [tensor([[ 1.8865],
#         [-3.1659]], requires_grad=True), tensor([3.9565], requires_grad=True)]
# Params are: [tensor([[ 1.8876],
#         [-3.1748]], requires_grad=True), tensor([3.9565], requires_grad=True)]
# Params are: [tensor([[ 1.8876],
#         [-3.1748]], requires_grad=True), tensor([3.9660], requires_grad=True)]
# Params are: [tensor([[ 1.8899],
#         [-3.1823]], requires_grad=True), tensor([3.9660], requires_grad=True)]
# Params are: [tensor([[ 1.8899],
#         [-3.1823]], requires_grad=True), tensor([3.9715], requires_grad=True)]
# Params are: [tensor([[ 1.8953],
#         [-3.1861]], requires_grad=True), tensor([3.9715], requires_grad=True)]
# Params are: [tensor([[ 1.8953],
#         [-3.1861]], requires_grad=True), tensor([3.9764], requires_grad=True)]
# Params are: [tensor([[ 1.9013],
#         [-3.1938]], requires_grad=True), tensor([3.9764], requires_grad=True)]
# Params are: [tensor([[ 1.9013],
#         [-3.1938]], requires_grad=True), tensor([3.9845], requires_grad=True)]
# Params are: [tensor([[ 1.9067],
#         [-3.1996]], requires_grad=True), tensor([3.9845], requires_grad=True)]
# Params are: [tensor([[ 1.9067],
#         [-3.1996]], requires_grad=True), tensor([3.9923], requires_grad=True)]
# Params are: [tensor([[ 1.9078],
#         [-3.2058]], requires_grad=True), tensor([3.9923], requires_grad=True)]
# Params are: [tensor([[ 1.9078],
#         [-3.2058]], requires_grad=True), tensor([4.0003], requires_grad=True)]
# Params are: [tensor([[ 1.9106],
#         [-3.2119]], requires_grad=True), tensor([4.0003], requires_grad=True)]
# Params are: [tensor([[ 1.9106],
#         [-3.2119]], requires_grad=True), tensor([4.0071], requires_grad=True)]
# Params are: [tensor([[ 1.9121],
#         [-3.2189]], requires_grad=True), tensor([4.0071], requires_grad=True)]
# Params are: [tensor([[ 1.9121],
#         [-3.2189]], requires_grad=True), tensor([4.0140], requires_grad=True)]
# Params are: [tensor([[ 1.9150],
#         [-3.2237]], requires_grad=True), tensor([4.0140], requires_grad=True)]
# Params are: [tensor([[ 1.9150],
#         [-3.2237]], requires_grad=True), tensor([4.0199], requires_grad=True)]
# Params are: [tensor([[ 1.9184],
#         [-3.2281]], requires_grad=True), tensor([4.0199], requires_grad=True)]
# Params are: [tensor([[ 1.9184],
#         [-3.2281]], requires_grad=True), tensor([4.0258], requires_grad=True)]
# Params are: [tensor([[ 1.9210],
#         [-3.2314]], requires_grad=True), tensor([4.0258], requires_grad=True)]
# Params are: [tensor([[ 1.9210],
#         [-3.2314]], requires_grad=True), tensor([4.0318], requires_grad=True)]
# Params are: [tensor([[ 1.9247],
#         [-3.2365]], requires_grad=True), tensor([4.0318], requires_grad=True)]
# Params are: [tensor([[ 1.9247],
#         [-3.2365]], requires_grad=True), tensor([4.0362], requires_grad=True)]
# Params are: [tensor([[ 1.9258],
#         [-3.2423]], requires_grad=True), tensor([4.0362], requires_grad=True)]
# Params are: [tensor([[ 1.9258],
#         [-3.2423]], requires_grad=True), tensor([4.0409], requires_grad=True)]
# Params are: [tensor([[ 1.9265],
#         [-3.2466]], requires_grad=True), tensor([4.0409], requires_grad=True)]
# Params are: [tensor([[ 1.9265],
#         [-3.2466]], requires_grad=True), tensor([4.0446], requires_grad=True)]
# Params are: [tensor([[ 1.9298],
#         [-3.2557]], requires_grad=True), tensor([4.0446], requires_grad=True)]
# Params are: [tensor([[ 1.9298],
#         [-3.2557]], requires_grad=True), tensor([4.0522], requires_grad=True)]
# Params are: [tensor([[ 1.9307],
#         [-3.2576]], requires_grad=True), tensor([4.0522], requires_grad=True)]
# Params are: [tensor([[ 1.9307],
#         [-3.2576]], requires_grad=True), tensor([4.0543], requires_grad=True)]
# Params are: [tensor([[ 1.9312],
#         [-3.2620]], requires_grad=True), tensor([4.0543], requires_grad=True)]
# Params are: [tensor([[ 1.9312],
#         [-3.2620]], requires_grad=True), tensor([4.0589], requires_grad=True)]
# Params are: [tensor([[ 1.9325],
#         [-3.2664]], requires_grad=True), tensor([4.0589], requires_grad=True)]
# Params are: [tensor([[ 1.9325],
#         [-3.2664]], requires_grad=True), tensor([4.0644], requires_grad=True)]
# Params are: [tensor([[ 1.9352],
#         [-3.2702]], requires_grad=True), tensor([4.0644], requires_grad=True)]
# Params are: [tensor([[ 1.9352],
#         [-3.2702]], requires_grad=True), tensor([4.0696], requires_grad=True)]
# Params are: [tensor([[ 1.9377],
#         [-3.2747]], requires_grad=True), tensor([4.0696], requires_grad=True)]
# Params are: [tensor([[ 1.9377],
#         [-3.2747]], requires_grad=True), tensor([4.0739], requires_grad=True)]
# Params are: [tensor([[ 1.9405],
#         [-3.2805]], requires_grad=True), tensor([4.0739], requires_grad=True)]
# Params are: [tensor([[ 1.9405],
#         [-3.2805]], requires_grad=True), tensor([4.0787], requires_grad=True)]
# Params are: [tensor([[ 1.9423],
#         [-3.2838]], requires_grad=True), tensor([4.0787], requires_grad=True)]
# Params are: [tensor([[ 1.9423],
#         [-3.2838]], requires_grad=True), tensor([4.0826], requires_grad=True)]
# Params are: [tensor([[ 1.9439],
#         [-3.2880]], requires_grad=True), tensor([4.0826], requires_grad=True)]
# Params are: [tensor([[ 1.9439],
#         [-3.2880]], requires_grad=True), tensor([4.0864], requires_grad=True)]
# Params are: [tensor([[ 1.9466],
#         [-3.2912]], requires_grad=True), tensor([4.0864], requires_grad=True)]
# Params are: [tensor([[ 1.9466],
#         [-3.2912]], requires_grad=True), tensor([4.0897], requires_grad=True)]
# Params are: [tensor([[ 1.9484],
#         [-3.2943]], requires_grad=True), tensor([4.0897], requires_grad=True)]
# Params are: [tensor([[ 1.9484],
#         [-3.2943]], requires_grad=True), tensor([4.0928], requires_grad=True)]
# Params are: [tensor([[ 1.9498],
#         [-3.2990]], requires_grad=True), tensor([4.0928], requires_grad=True)]
# Params are: [tensor([[ 1.9498],
#         [-3.2990]], requires_grad=True), tensor([4.0960], requires_grad=True)]
# Params are: [tensor([[ 1.9503],
#         [-3.3018]], requires_grad=True), tensor([4.0960], requires_grad=True)]
# Params are: [tensor([[ 1.9503],
#         [-3.3018]], requires_grad=True), tensor([4.0992], requires_grad=True)]
# Params are: [tensor([[ 1.9498],
#         [-3.3043]], requires_grad=True), tensor([4.0992], requires_grad=True)]
# Params are: [tensor([[ 1.9498],
#         [-3.3043]], requires_grad=True), tensor([4.1018], requires_grad=True)]
# Params are: [tensor([[ 1.9519],
#         [-3.3074]], requires_grad=True), tensor([4.1018], requires_grad=True)]
# Params are: [tensor([[ 1.9519],
#         [-3.3074]], requires_grad=True), tensor([4.1051], requires_grad=True)]
# Params are: [tensor([[ 1.9531],
#         [-3.3108]], requires_grad=True), tensor([4.1051], requires_grad=True)]
# Params are: [tensor([[ 1.9531],
#         [-3.3108]], requires_grad=True), tensor([4.1080], requires_grad=True)]
# Params are: [tensor([[ 1.9550],
#         [-3.3124]], requires_grad=True), tensor([4.1080], requires_grad=True)]
# Params are: [tensor([[ 1.9550],
#         [-3.3124]], requires_grad=True), tensor([4.1105], requires_grad=True)]
# Params are: [tensor([[ 1.9569],
#         [-3.3143]], requires_grad=True), tensor([4.1105], requires_grad=True)]
# Params are: [tensor([[ 1.9569],
#         [-3.3143]], requires_grad=True), tensor([4.1141], requires_grad=True)]
# Params are: [tensor([[ 1.9576],
#         [-3.3175]], requires_grad=True), tensor([4.1141], requires_grad=True)]
# Params are: [tensor([[ 1.9576],
#         [-3.3175]], requires_grad=True), tensor([4.1177], requires_grad=True)]
# Params are: [tensor([[ 1.9570],
#         [-3.3205]], requires_grad=True), tensor([4.1177], requires_grad=True)]
# Params are: [tensor([[ 1.9570],
#         [-3.3205]], requires_grad=True), tensor([4.1194], requires_grad=True)]
# Params are: [tensor([[ 1.9583],
#         [-3.3217]], requires_grad=True), tensor([4.1194], requires_grad=True)]
# Params are: [tensor([[ 1.9583],
#         [-3.3217]], requires_grad=True), tensor([4.1201], requires_grad=True)]
# Params are: [tensor([[ 1.9591],
#         [-3.3237]], requires_grad=True), tensor([4.1201], requires_grad=True)]
# Params are: [tensor([[ 1.9591],
#         [-3.3237]], requires_grad=True), tensor([4.1221], requires_grad=True)]
# Params are: [tensor([[ 1.9612],
#         [-3.3251]], requires_grad=True), tensor([4.1221], requires_grad=True)]
# Params are: [tensor([[ 1.9612],
#         [-3.3251]], requires_grad=True), tensor([4.1251], requires_grad=True)]
# Params are: [tensor([[ 1.9626],
#         [-3.3283]], requires_grad=True), tensor([4.1251], requires_grad=True)]
# Params are: [tensor([[ 1.9626],
#         [-3.3283]], requires_grad=True), tensor([4.1276], requires_grad=True)]
# Params are: [tensor([[ 1.9637],
#         [-3.3309]], requires_grad=True), tensor([4.1276], requires_grad=True)]
# Params are: [tensor([[ 1.9637],
#         [-3.3309]], requires_grad=True), tensor([4.1304], requires_grad=True)]
# Params are: [tensor([[ 1.9639],
#         [-3.3318]], requires_grad=True), tensor([4.1304], requires_grad=True)]
# Params are: [tensor([[ 1.9639],
#         [-3.3318]], requires_grad=True), tensor([4.1330], requires_grad=True)]
# Params are: [tensor([[ 1.9645],
#         [-3.3344]], requires_grad=True), tensor([4.1330], requires_grad=True)]
# Params are: [tensor([[ 1.9645],
#         [-3.3344]], requires_grad=True), tensor([4.1359], requires_grad=True)]
# Params are: [tensor([[ 1.9640],
#         [-3.3352]], requires_grad=True), tensor([4.1359], requires_grad=True)]
# Params are: [tensor([[ 1.9640],
#         [-3.3352]], requires_grad=True), tensor([4.1379], requires_grad=True)]
# Params are: [tensor([[ 1.9642],
#         [-3.3384]], requires_grad=True), tensor([4.1379], requires_grad=True)]
# Params are: [tensor([[ 1.9642],
#         [-3.3384]], requires_grad=True), tensor([4.1404], requires_grad=True)]
# Params are: [tensor([[ 1.9654],
#         [-3.3407]], requires_grad=True), tensor([4.1404], requires_grad=True)]
# Params are: [tensor([[ 1.9654],
#         [-3.3407]], requires_grad=True), tensor([4.1424], requires_grad=True)]
# Params are: [tensor([[ 1.9675],
#         [-3.3420]], requires_grad=True), tensor([4.1424], requires_grad=True)]
# Params are: [tensor([[ 1.9675],
#         [-3.3420]], requires_grad=True), tensor([4.1445], requires_grad=True)]
# Params are: [tensor([[ 1.9695],
#         [-3.3452]], requires_grad=True), tensor([4.1445], requires_grad=True)]
# Params are: [tensor([[ 1.9695],
#         [-3.3452]], requires_grad=True), tensor([4.1460], requires_grad=True)]
# Params are: [tensor([[ 1.9714],
#         [-3.3455]], requires_grad=True), tensor([4.1460], requires_grad=True)]
# Params are: [tensor([[ 1.9714],
#         [-3.3455]], requires_grad=True), tensor([4.1477], requires_grad=True)]
# Params are: [tensor([[ 1.9722],
#         [-3.3475]], requires_grad=True), tensor([4.1477], requires_grad=True)]
# Params are: [tensor([[ 1.9722],
#         [-3.3475]], requires_grad=True), tensor([4.1485], requires_grad=True)]
# Params are: [tensor([[ 1.9729],
#         [-3.3486]], requires_grad=True), tensor([4.1485], requires_grad=True)]
# Params are: [tensor([[ 1.9729],
#         [-3.3486]], requires_grad=True), tensor([4.1498], requires_grad=True)]
# Params are: [tensor([[ 1.9729],
#         [-3.3509]], requires_grad=True), tensor([4.1498], requires_grad=True)]
# Params are: [tensor([[ 1.9729],
#         [-3.3509]], requires_grad=True), tensor([4.1522], requires_grad=True)]
# Params are: [tensor([[ 1.9740],
#         [-3.3536]], requires_grad=True), tensor([4.1522], requires_grad=True)]
# Params are: [tensor([[ 1.9740],
#         [-3.3536]], requires_grad=True), tensor([4.1542], requires_grad=True)]
# Params are: [tensor([[ 1.9758],
#         [-3.3556]], requires_grad=True), tensor([4.1542], requires_grad=True)]
# Params are: [tensor([[ 1.9758],
#         [-3.3556]], requires_grad=True), tensor([4.1550], requires_grad=True)]
# Params are: [tensor([[ 1.9779],
#         [-3.3558]], requires_grad=True), tensor([4.1550], requires_grad=True)]
# Params are: [tensor([[ 1.9779],
#         [-3.3558]], requires_grad=True), tensor([4.1569], requires_grad=True)]
# Params are: [tensor([[ 1.9783],
#         [-3.3578]], requires_grad=True), tensor([4.1569], requires_grad=True)]
# Params are: [tensor([[ 1.9783],
#         [-3.3578]], requires_grad=True), tensor([4.1592], requires_grad=True)]
# Params are: [tensor([[ 1.9783],
#         [-3.3596]], requires_grad=True), tensor([4.1592], requires_grad=True)]
# Params are: [tensor([[ 1.9783],
#         [-3.3596]], requires_grad=True), tensor([4.1614], requires_grad=True)]
# Params are: [tensor([[ 1.9790],
#         [-3.3612]], requires_grad=True), tensor([4.1614], requires_grad=True)]
# Params are: [tensor([[ 1.9790],
#         [-3.3612]], requires_grad=True), tensor([4.1619], requires_grad=True)]
# Params are: [tensor([[ 1.9798],
#         [-3.3627]], requires_grad=True), tensor([4.1619], requires_grad=True)]
# Params are: [tensor([[ 1.9798],
#         [-3.3627]], requires_grad=True), tensor([4.1629], requires_grad=True)]
# Params are: [tensor([[ 1.9805],
#         [-3.3634]], requires_grad=True), tensor([4.1629], requires_grad=True)]
# Params are: [tensor([[ 1.9805],
#         [-3.3634]], requires_grad=True), tensor([4.1640], requires_grad=True)]
# Params are: [tensor([[ 1.9806],
#         [-3.3653]], requires_grad=True), tensor([4.1640], requires_grad=True)]
# Params are: [tensor([[ 1.9806],
#         [-3.3653]], requires_grad=True), tensor([4.1646], requires_grad=True)]
# Params are: [tensor([[ 1.9806],
#         [-3.3663]], requires_grad=True), tensor([4.1646], requires_grad=True)]
# Params are: [tensor([[ 1.9806],
#         [-3.3663]], requires_grad=True), tensor([4.1651], requires_grad=True)]
# Params are: [tensor([[ 1.9816],
#         [-3.3672]], requires_grad=True), tensor([4.1651], requires_grad=True)]
# Params are: [tensor([[ 1.9816],
#         [-3.3672]], requires_grad=True), tensor([4.1668], requires_grad=True)]
# Params are: [tensor([[ 1.9819],
#         [-3.3671]], requires_grad=True), tensor([4.1668], requires_grad=True)]
# Params are: [tensor([[ 1.9819],
#         [-3.3671]], requires_grad=True), tensor([4.1673], requires_grad=True)]
# Params are: [tensor([[ 1.9834],
#         [-3.3673]], requires_grad=True), tensor([4.1673], requires_grad=True)]
# Params are: [tensor([[ 1.9834],
#         [-3.3673]], requires_grad=True), tensor([4.1678], requires_grad=True)]
# Params are: [tensor([[ 1.9837],
#         [-3.3676]], requires_grad=True), tensor([4.1678], requires_grad=True)]
# Params are: [tensor([[ 1.9837],
#         [-3.3676]], requires_grad=True), tensor([4.1692], requires_grad=True)]
# Params are: [tensor([[ 1.9843],
#         [-3.3678]], requires_grad=True), tensor([4.1692], requires_grad=True)]
# Params are: [tensor([[ 1.9843],
#         [-3.3678]], requires_grad=True), tensor([4.1700], requires_grad=True)]
# Params are: [tensor([[ 1.9848],
#         [-3.3691]], requires_grad=True), tensor([4.1700], requires_grad=True)]
# Params are: [tensor([[ 1.9848],
#         [-3.3691]], requires_grad=True), tensor([4.1717], requires_grad=True)]
# Params are: [tensor([[ 1.9849],
#         [-3.3696]], requires_grad=True), tensor([4.1717], requires_grad=True)]
# Params are: [tensor([[ 1.9849],
#         [-3.3696]], requires_grad=True), tensor([4.1715], requires_grad=True)]
# Params are: [tensor([[ 1.9847],
#         [-3.3706]], requires_grad=True), tensor([4.1715], requires_grad=True)]
# Params are: [tensor([[ 1.9847],
#         [-3.3706]], requires_grad=True), tensor([4.1719], requires_grad=True)]
# Params are: [tensor([[ 1.9858],
#         [-3.3713]], requires_grad=True), tensor([4.1719], requires_grad=True)]
# Params are: [tensor([[ 1.9858],
#         [-3.3713]], requires_grad=True), tensor([4.1730], requires_grad=True)]
# Params are: [tensor([[ 1.9852],
#         [-3.3726]], requires_grad=True), tensor([4.1730], requires_grad=True)]
# Params are: [tensor([[ 1.9852],
#         [-3.3726]], requires_grad=True), tensor([4.1735], requires_grad=True)]
# Params are: [tensor([[ 1.9850],
#         [-3.3734]], requires_grad=True), tensor([4.1735], requires_grad=True)]
# Params are: [tensor([[ 1.9850],
#         [-3.3734]], requires_grad=True), tensor([4.1744], requires_grad=True)]
# Params are: [tensor([[ 1.9854],
#         [-3.3746]], requires_grad=True), tensor([4.1744], requires_grad=True)]
# Params are: [tensor([[ 1.9854],
#         [-3.3746]], requires_grad=True), tensor([4.1756], requires_grad=True)]
# Params are: [tensor([[ 1.9858],
#         [-3.3744]], requires_grad=True), tensor([4.1756], requires_grad=True)]
# Params are: [tensor([[ 1.9858],
#         [-3.3744]], requires_grad=True), tensor([4.1761], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3750]], requires_grad=True), tensor([4.1761], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3750]], requires_grad=True), tensor([4.1767], requires_grad=True)]
# Params are: [tensor([[ 1.9873],
#         [-3.3757]], requires_grad=True), tensor([4.1767], requires_grad=True)]
# Params are: [tensor([[ 1.9873],
#         [-3.3757]], requires_grad=True), tensor([4.1766], requires_grad=True)]
# Params are: [tensor([[ 1.9881],
#         [-3.3758]], requires_grad=True), tensor([4.1766], requires_grad=True)]
# Params are: [tensor([[ 1.9881],
#         [-3.3758]], requires_grad=True), tensor([4.1775], requires_grad=True)]
# Params are: [tensor([[ 1.9886],
#         [-3.3770]], requires_grad=True), tensor([4.1775], requires_grad=True)]
# Params are: [tensor([[ 1.9886],
#         [-3.3770]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9882],
#         [-3.3775]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9882],
#         [-3.3775]], requires_grad=True), tensor([4.1788], requires_grad=True)]
# Params are: [tensor([[ 1.9884],
#         [-3.3785]], requires_grad=True), tensor([4.1788], requires_grad=True)]
# Params are: [tensor([[ 1.9884],
#         [-3.3785]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3792]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3792]], requires_grad=True), tensor([4.1798], requires_grad=True)]
# Params are: [tensor([[ 1.9873],
#         [-3.3793]], requires_grad=True), tensor([4.1798], requires_grad=True)]
# Params are: [tensor([[ 1.9873],
#         [-3.3793]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3807]], requires_grad=True), tensor([4.1793], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3807]], requires_grad=True), tensor([4.1799], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3809]], requires_grad=True), tensor([4.1799], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3809]], requires_grad=True), tensor([4.1806], requires_grad=True)]
# Params are: [tensor([[ 1.9884],
#         [-3.3808]], requires_grad=True), tensor([4.1806], requires_grad=True)]
# Params are: [tensor([[ 1.9884],
#         [-3.3808]], requires_grad=True), tensor([4.1800], requires_grad=True)]
# Params are: [tensor([[ 1.9886],
#         [-3.3810]], requires_grad=True), tensor([4.1800], requires_grad=True)]
# Params are: [tensor([[ 1.9886],
#         [-3.3810]], requires_grad=True), tensor([4.1811], requires_grad=True)]
# Params are: [tensor([[ 1.9887],
#         [-3.3813]], requires_grad=True), tensor([4.1811], requires_grad=True)]
# Params are: [tensor([[ 1.9887],
#         [-3.3813]], requires_grad=True), tensor([4.1819], requires_grad=True)]
# Params are: [tensor([[ 1.9877],
#         [-3.3828]], requires_grad=True), tensor([4.1819], requires_grad=True)]
# Params are: [tensor([[ 1.9877],
#         [-3.3828]], requires_grad=True), tensor([4.1827], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3845]], requires_grad=True), tensor([4.1827], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3845]], requires_grad=True), tensor([4.1833], requires_grad=True)]
# Params are: [tensor([[ 1.9874],
#         [-3.3851]], requires_grad=True), tensor([4.1833], requires_grad=True)]
# Params are: [tensor([[ 1.9874],
#         [-3.3851]], requires_grad=True), tensor([4.1839], requires_grad=True)]
# Params are: [tensor([[ 1.9867],
#         [-3.3852]], requires_grad=True), tensor([4.1839], requires_grad=True)]
# Params are: [tensor([[ 1.9867],
#         [-3.3852]], requires_grad=True), tensor([4.1848], requires_grad=True)]
# Params are: [tensor([[ 1.9867],
#         [-3.3854]], requires_grad=True), tensor([4.1848], requires_grad=True)]
# Params are: [tensor([[ 1.9867],
#         [-3.3854]], requires_grad=True), tensor([4.1852], requires_grad=True)]
# Params are: [tensor([[ 1.9864],
#         [-3.3857]], requires_grad=True), tensor([4.1852], requires_grad=True)]
# Params are: [tensor([[ 1.9864],
#         [-3.3857]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3855]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9871],
#         [-3.3855]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9874],
#         [-3.3854]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9874],
#         [-3.3854]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3864]], requires_grad=True), tensor([4.1858], requires_grad=True)]
# Params are: [tensor([[ 1.9880],
#         [-3.3864]], requires_grad=True), tensor([4.1860], requires_grad=True)]
# Params are: [tensor([[ 1.9892],
#         [-3.3868]], requires_grad=True), tensor([4.1860], requires_grad=True)]
# Params are: [tensor([[ 1.9892],
#         [-3.3868]], requires_grad=True), tensor([4.1865], requires_grad=True)]
# Params are: [tensor([[ 1.9897],
#         [-3.3862]], requires_grad=True), tensor([4.1865], requires_grad=True)]
# Params are: [tensor([[ 1.9897],
#         [-3.3862]], requires_grad=True), tensor([4.1869], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3862]], requires_grad=True), tensor([4.1869], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3862]], requires_grad=True), tensor([4.1873], requires_grad=True)]
# Params are: [tensor([[ 1.9913],
#         [-3.3872]], requires_grad=True), tensor([4.1873], requires_grad=True)]
# Params are: [tensor([[ 1.9913],
#         [-3.3872]], requires_grad=True), tensor([4.1894], requires_grad=True)]
# Params are: [tensor([[ 1.9915],
#         [-3.3888]], requires_grad=True), tensor([4.1894], requires_grad=True)]
# Params are: [tensor([[ 1.9915],
#         [-3.3888]], requires_grad=True), tensor([4.1905], requires_grad=True)]
# Params are: [tensor([[ 1.9916],
#         [-3.3881]], requires_grad=True), tensor([4.1905], requires_grad=True)]
# Params are: [tensor([[ 1.9916],
#         [-3.3881]], requires_grad=True), tensor([4.1912], requires_grad=True)]
# Params are: [tensor([[ 1.9920],
#         [-3.3888]], requires_grad=True), tensor([4.1912], requires_grad=True)]
# Params are: [tensor([[ 1.9920],
#         [-3.3888]], requires_grad=True), tensor([4.1908], requires_grad=True)]
# Params are: [tensor([[ 1.9919],
#         [-3.3890]], requires_grad=True), tensor([4.1908], requires_grad=True)]
# Params are: [tensor([[ 1.9919],
#         [-3.3890]], requires_grad=True), tensor([4.1917], requires_grad=True)]
# Params are: [tensor([[ 1.9926],
#         [-3.3893]], requires_grad=True), tensor([4.1917], requires_grad=True)]
# Params are: [tensor([[ 1.9926],
#         [-3.3893]], requires_grad=True), tensor([4.1927], requires_grad=True)]
# Params are: [tensor([[ 1.9928],
#         [-3.3903]], requires_grad=True), tensor([4.1927], requires_grad=True)]
# Params are: [tensor([[ 1.9928],
#         [-3.3903]], requires_grad=True), tensor([4.1935], requires_grad=True)]
# Params are: [tensor([[ 1.9925],
#         [-3.3912]], requires_grad=True), tensor([4.1935], requires_grad=True)]
# Params are: [tensor([[ 1.9925],
#         [-3.3912]], requires_grad=True), tensor([4.1945], requires_grad=True)]
# Params are: [tensor([[ 1.9924],
#         [-3.3906]], requires_grad=True), tensor([4.1945], requires_grad=True)]
# Params are: [tensor([[ 1.9924],
#         [-3.3906]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9922],
#         [-3.3909]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9922],
#         [-3.3909]], requires_grad=True), tensor([4.1930], requires_grad=True)]
# Params are: [tensor([[ 1.9921],
#         [-3.3918]], requires_grad=True), tensor([4.1930], requires_grad=True)]
# Params are: [tensor([[ 1.9921],
#         [-3.3918]], requires_grad=True), tensor([4.1929], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3925]], requires_grad=True), tensor([4.1929], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3925]], requires_grad=True), tensor([4.1925], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3927]], requires_grad=True), tensor([4.1925], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3927]], requires_grad=True), tensor([4.1918], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3917]], requires_grad=True), tensor([4.1918], requires_grad=True)]
# Params are: [tensor([[ 1.9914],
#         [-3.3917]], requires_grad=True), tensor([4.1932], requires_grad=True)]
# Params are: [tensor([[ 1.9918],
#         [-3.3917]], requires_grad=True), tensor([4.1932], requires_grad=True)]
# Params are: [tensor([[ 1.9918],
#         [-3.3917]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9909],
#         [-3.3911]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9909],
#         [-3.3911]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9900],
#         [-3.3929]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9900],
#         [-3.3929]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3926]], requires_grad=True), tensor([4.1931], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3926]], requires_grad=True), tensor([4.1933], requires_grad=True)]
# Params are: [tensor([[ 1.9907],
#         [-3.3916]], requires_grad=True), tensor([4.1933], requires_grad=True)]
# Params are: [tensor([[ 1.9907],
#         [-3.3916]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9898],
#         [-3.3925]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9898],
#         [-3.3925]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9900],
#         [-3.3923]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9900],
#         [-3.3923]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9903],
#         [-3.3926]], requires_grad=True), tensor([4.1937], requires_grad=True)]
# Params are: [tensor([[ 1.9903],
#         [-3.3926]], requires_grad=True), tensor([4.1936], requires_grad=True)]
# Params are: [tensor([[ 1.9906],
#         [-3.3922]], requires_grad=True), tensor([4.1936], requires_grad=True)]
# Params are: [tensor([[ 1.9906],
#         [-3.3922]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3929]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9908],
#         [-3.3929]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9910],
#         [-3.3930]], requires_grad=True), tensor([4.1944], requires_grad=True)]
# Params are: [tensor([[ 1.9910],
#         [-3.3930]], requires_grad=True), tensor([4.1939], requires_grad=True)]
# Params are: [tensor([[ 1.9894],
#         [-3.3929]], requires_grad=True), tensor([4.1939], requires_grad=True)]
# Params are: [tensor([[ 1.9894],
#         [-3.3929]], requires_grad=True), tensor([4.1943], requires_grad=True)]
# Params are: [tensor([[ 1.9893],
#         [-3.3931]], requires_grad=True), tensor([4.1943], requires_grad=True)]
# Params are: [tensor([[ 1.9893],
# ...
# Params are: [tensor([[ 1.9959],
#         [-3.4001]], requires_grad=True), tensor([4.1983], requires_grad=True)]
# Params are: [tensor([[ 1.9959],
#         [-3.4001]], requires_grad=True), tensor([4.1982], requires_grad=True)]
# Params are: [tensor([[ 1.9955],
#         [-3.3999]], requires_grad=True), tensor([4.1982], requires_grad=True)]
# Params are: [tensor([[ 1.9955],
#         [-3.3999]], requires_grad=True), tensor([4.1983], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.4003]], requires_grad=True), tensor([4.1983], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.4003]], requires_grad=True), tensor([4.1987], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.4008]], requires_grad=True), tensor([4.1987], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.4008]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.4014]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.4014]], requires_grad=True), tensor([4.1994], requires_grad=True)]
# Params are: [tensor([[ 1.9953],
#         [-3.4016]], requires_grad=True), tensor([4.1994], requires_grad=True)]
# Params are: [tensor([[ 1.9953],
#         [-3.4016]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.4014]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.4014]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9972],
#         [-3.4014]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9972],
#         [-3.4014]], requires_grad=True), tensor([4.2006], requires_grad=True)]
# Params are: [tensor([[ 1.9976],
#         [-3.3985]], requires_grad=True), tensor([4.2006], requires_grad=True)]
# Params are: [tensor([[ 1.9976],
#         [-3.3985]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9974],
#         [-3.3978]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9974],
#         [-3.3978]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9974],
#         [-3.3975]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9974],
#         [-3.3975]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9968],
#         [-3.3961]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9968],
#         [-3.3961]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9969],
#         [-3.3961]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9969],
#         [-3.3961]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3965]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3965]], requires_grad=True), tensor([4.1993], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.3976]], requires_grad=True), tensor([4.1993], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.3976]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9973],
#         [-3.3971]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9973],
#         [-3.3971]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9971],
#         [-3.3980]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9971],
#         [-3.3980]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9970],
#         [-3.3971]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9970],
#         [-3.3971]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9982],
#         [-3.3973]], requires_grad=True), tensor([4.1998], requires_grad=True)]
# Params are: [tensor([[ 1.9982],
#         [-3.3973]], requires_grad=True), tensor([4.2003], requires_grad=True)]
# Params are: [tensor([[ 1.9995],
#         [-3.3978]], requires_grad=True), tensor([4.2003], requires_grad=True)]
# Params are: [tensor([[ 1.9995],
#         [-3.3978]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9994],
#         [-3.3984]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9994],
#         [-3.3984]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9996],
#         [-3.3982]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9996],
#         [-3.3982]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9998],
#         [-3.3985]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9998],
#         [-3.3985]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3986]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3986]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9996],
#         [-3.3981]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9996],
#         [-3.3981]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9994],
#         [-3.3985]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9994],
#         [-3.3985]], requires_grad=True), tensor([4.2011], requires_grad=True)]
# Params are: [tensor([[ 1.9987],
#         [-3.3984]], requires_grad=True), tensor([4.2011], requires_grad=True)]
# Params are: [tensor([[ 1.9987],
#         [-3.3984]], requires_grad=True), tensor([4.2007], requires_grad=True)]
# Params are: [tensor([[ 1.9989],
#         [-3.3987]], requires_grad=True), tensor([4.2007], requires_grad=True)]
# Params are: [tensor([[ 1.9989],
#         [-3.3987]], requires_grad=True), tensor([4.2013], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3979]], requires_grad=True), tensor([4.2013], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3979]], requires_grad=True), tensor([4.2013], requires_grad=True)]
# Params are: [tensor([[ 1.9997],
#         [-3.3979]], requires_grad=True), tensor([4.2013], requires_grad=True)]
# Params are: [tensor([[ 1.9997],
#         [-3.3979]], requires_grad=True), tensor([4.2010], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3987]], requires_grad=True), tensor([4.2010], requires_grad=True)]
# Params are: [tensor([[ 1.9993],
#         [-3.3987]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 1.9995],
#         [-3.3985]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 1.9995],
#         [-3.3985]], requires_grad=True), tensor([4.2021], requires_grad=True)]
# Params are: [tensor([[ 2.0011],
#         [-3.3983]], requires_grad=True), tensor([4.2021], requires_grad=True)]
# Params are: [tensor([[ 2.0011],
#         [-3.3983]], requires_grad=True), tensor([4.2028], requires_grad=True)]
# Params are: [tensor([[ 2.0008],
#         [-3.3987]], requires_grad=True), tensor([4.2028], requires_grad=True)]
# Params are: [tensor([[ 2.0008],
#         [-3.3987]], requires_grad=True), tensor([4.2030], requires_grad=True)]
# Params are: [tensor([[ 2.0012],
#         [-3.3993]], requires_grad=True), tensor([4.2030], requires_grad=True)]
# Params are: [tensor([[ 2.0012],
#         [-3.3993]], requires_grad=True), tensor([4.2024], requires_grad=True)]
# Params are: [tensor([[ 2.0015],
#         [-3.4001]], requires_grad=True), tensor([4.2024], requires_grad=True)]
# Params are: [tensor([[ 2.0015],
#         [-3.4001]], requires_grad=True), tensor([4.2031], requires_grad=True)]
# Params are: [tensor([[ 2.0016],
#         [-3.4007]], requires_grad=True), tensor([4.2031], requires_grad=True)]
# Params are: [tensor([[ 2.0016],
#         [-3.4007]], requires_grad=True), tensor([4.2020], requires_grad=True)]
# Params are: [tensor([[ 2.0010],
#         [-3.3998]], requires_grad=True), tensor([4.2020], requires_grad=True)]
# Params are: [tensor([[ 2.0010],
#         [-3.3998]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 2.0002],
#         [-3.3998]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 2.0002],
#         [-3.3998]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 2.0003],
#         [-3.3996]], requires_grad=True), tensor([4.2017], requires_grad=True)]
# Params are: [tensor([[ 2.0003],
#         [-3.3996]], requires_grad=True), tensor([4.2020], requires_grad=True)]
# Params are: [tensor([[ 1.9999],
#         [-3.3997]], requires_grad=True), tensor([4.2020], requires_grad=True)]
# Params are: [tensor([[ 1.9999],
#         [-3.3997]], requires_grad=True), tensor([4.2015], requires_grad=True)]
# Params are: [tensor([[ 1.9986],
#         [-3.4003]], requires_grad=True), tensor([4.2015], requires_grad=True)]
# Params are: [tensor([[ 1.9986],
#         [-3.4003]], requires_grad=True), tensor([4.2008], requires_grad=True)]
# Params are: [tensor([[ 1.9981],
#         [-3.4002]], requires_grad=True), tensor([4.2008], requires_grad=True)]
# Params are: [tensor([[ 1.9981],
#         [-3.4002]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9977],
#         [-3.3996]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9977],
#         [-3.3996]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9969],
#         [-3.3993]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9969],
#         [-3.3993]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9964],
#         [-3.3988]], requires_grad=True), tensor([4.1997], requires_grad=True)]
# Params are: [tensor([[ 1.9964],
#         [-3.3988]], requires_grad=True), tensor([4.1994], requires_grad=True)]
# Params are: [tensor([[ 1.9967],
#         [-3.3986]], requires_grad=True), tensor([4.1994], requires_grad=True)]
# Params are: [tensor([[ 1.9967],
#         [-3.3986]], requires_grad=True), tensor([4.1982], requires_grad=True)]
# Params are: [tensor([[ 1.9971],
#         [-3.3989]], requires_grad=True), tensor([4.1982], requires_grad=True)]
# Params are: [tensor([[ 1.9971],
#         [-3.3989]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Params are: [tensor([[ 1.9977],
#         [-3.3987]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Params are: [tensor([[ 1.9977],
#         [-3.3987]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Params are: [tensor([[ 1.9980],
#         [-3.3993]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Params are: [tensor([[ 1.9980],
#         [-3.3993]], requires_grad=True), tensor([4.1974], requires_grad=True)]
# Params are: [tensor([[ 1.9965],
#         [-3.3993]], requires_grad=True), tensor([4.1974], requires_grad=True)]
# Params are: [tensor([[ 1.9965],
#         [-3.3993]], requires_grad=True), tensor([4.1977], requires_grad=True)]
# Params are: [tensor([[ 1.9967],
#         [-3.3991]], requires_grad=True), tensor([4.1977], requires_grad=True)]
# Params are: [tensor([[ 1.9967],
#         [-3.3991]], requires_grad=True), tensor([4.1962], requires_grad=True)]
# Params are: [tensor([[ 1.9960],
#         [-3.3992]], requires_grad=True), tensor([4.1962], requires_grad=True)]
# Params are: [tensor([[ 1.9960],
#         [-3.3992]], requires_grad=True), tensor([4.1970], requires_grad=True)]
# Params are: [tensor([[ 1.9959],
#         [-3.3988]], requires_grad=True), tensor([4.1970], requires_grad=True)]
# Params are: [tensor([[ 1.9959],
#         [-3.3988]], requires_grad=True), tensor([4.1971], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3980]], requires_grad=True), tensor([4.1971], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3980]], requires_grad=True), tensor([4.1974], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3981]], requires_grad=True), tensor([4.1974], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3981]], requires_grad=True), tensor([4.1980], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.3973]], requires_grad=True), tensor([4.1980], requires_grad=True)]
# Params are: [tensor([[ 1.9961],
#         [-3.3973]], requires_grad=True), tensor([4.1991], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3972]], requires_grad=True), tensor([4.1991], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3972]], requires_grad=True), tensor([4.1988], requires_grad=True)]
# Params are: [tensor([[ 1.9958],
#         [-3.3967]], requires_grad=True), tensor([4.1988], requires_grad=True)]
# Params are: [tensor([[ 1.9958],
#         [-3.3967]], requires_grad=True), tensor([4.1985], requires_grad=True)]
# Params are: [tensor([[ 1.9958],
#         [-3.3978]], requires_grad=True), tensor([4.1985], requires_grad=True)]
# Params are: [tensor([[ 1.9958],
#         [-3.3978]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3982]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3982]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.3985]], requires_grad=True), tensor([4.2001], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.3985]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3993]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9962],
#         [-3.3993]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3995]], requires_grad=True), tensor([4.1995], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3995]], requires_grad=True), tensor([4.1999], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.3992]], requires_grad=True), tensor([4.1999], requires_grad=True)]
# Params are: [tensor([[ 1.9963],
#         [-3.3992]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9951],
#         [-3.3990]], requires_grad=True), tensor([4.2002], requires_grad=True)]
# Params are: [tensor([[ 1.9951],
#         [-3.3990]], requires_grad=True), tensor([4.2000], requires_grad=True)]
# Params are: [tensor([[ 1.9941],
#         [-3.3999]], requires_grad=True), tensor([4.2000], requires_grad=True)]
# Params are: [tensor([[ 1.9941],
#         [-3.3999]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3995]], requires_grad=True), tensor([4.1996], requires_grad=True)]
# Params are: [tensor([[ 1.9954],
#         [-3.3995]], requires_grad=True), tensor([4.1988], requires_grad=True)]
# Params are: [tensor([[ 1.9948],
#         [-3.3995]], requires_grad=True), tensor([4.1988], requires_grad=True)]
# Params are: [tensor([[ 1.9948],
#         [-3.3995]], requires_grad=True), tensor([4.1987], requires_grad=True)]
# Params are: [tensor([[ 1.9951],
#         [-3.3999]], requires_grad=True), tensor([4.1987], requires_grad=True)]
# Params are: [tensor([[ 1.9951],
#         [-3.3999]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3993]], requires_grad=True), tensor([4.1986], requires_grad=True)]
# Params are: [tensor([[ 1.9957],
#         [-3.3993]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Params are: [tensor([[ 1.9967],
#         [-3.3985]], requires_grad=True), tensor([4.1979], requires_grad=True)]
# Estimated w: tensor([[ 1.9967],
#         [-3.3985]], requires_grad=True)
#  Estimated b: tensor([4.1975], requires_grad=True)
